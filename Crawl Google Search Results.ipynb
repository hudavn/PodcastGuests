# %%
import requests
from bs4 import BeautifulSoup
from requests_ip_rotator import ApiGateway, EXTRA_REGIONS
import time

# %%
f = open("compare.txt", "r")
data = f.read().split('\n')[:-1]
f.close()

# %%
# Create gateway object and initialise in AWS
gateway = ApiGateway("https://bing.com", regions=EXTRA_REGIONS, access_key_id="AKIAZ5PXI7SNBAVGCMGG", access_key_secret="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")
gateway.start(force = True)
headers = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"}
# Out:
# Starting API gateways in 17 regions.
# Using 17 endpoints with name 'https://bing.com - IP Rotate API' (17 new).

# %%
# Assign gateway to session
cnt = 0
stop = False
for keyword in data:
    print(keyword)
    for q in ['linkedin', 'company website']:
        url = f'https://bing.com/search?q={keyword} {q}'
        session = requests.Session()
        session.mount("https://ping.com/", gateway)

        resp = session.get(url, headers = headers)
#         print(resp.text)
        
        while (not resp.ok):
            resp = session.get(url, headers = headers)
            time.sleep(5)
            
        soup = BeautifulSoup(resp.text)
        res = soup.find('li', {'class': 'b_algo'})
        if res: print(res.find('a')['href'])
    if stop: break
    else: cnt+=1
    print()

# print(cnt)
# Out:
# Christina Scalera
# https://www.linkedin.com/in/christinascalera
# https://christinascalera.com/
#
# Julie Ball
# https://www.linkedin.com/in/julieball
# https://www.julieballdesign.co.uk/
#
# Kristen Brown
# https://www.linkedin.com/pub/dir/kristen/brown
# https://kristenbrowngolden.org/
#
# Alexis "Lex" Monson
# https://www.linkedin.com/in/alexis-monson-b5b35922
# https://www.linkedin.com/in/alexis-monson-b5b35922
#
# Natarsha Wright
# https://www.linkedin.com/pub/dir/natasha/wright
# https://www.wright.com/corporate
#
# Liz Rich
# https://www.linkedin.com/in/lizrich1
# http://www.crickethillpottery.com/
#
# Kylie Clayborne
# https://www.linkedin.com/in/kylie-clayborne-9985ba119
# https://www.kylieclayborne.com/social-links
#
# Molly Beck
# https://www.linkedin.com/pub/dir/molly/beck
# https://msmollybeck.com/
#
# Dr. Lindsay Padilla
# https://www.linkedin.com/in/lindsaypadilla
# https://lindsaympadilla.com/
#
# Vanessa Ryan
# https://www.linkedin.com/in/vanessa-ryan
# ...

# %%
print(cnt)
# Delete gateways
# gateway.shutdown()
# Out:
# 1238
